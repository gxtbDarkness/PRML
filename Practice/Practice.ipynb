# %% [markdown]
# # 实践作业
# 从四类方法中选三类方法，从选定的每类方法中，各选一种具体的方法，从给定的数据集中选一个数据集对这三种方法进行测试比较。
#
# 本作业采用手写数字识别 Mnist 数据集

# %% [markdown]
# 导入需要使用的库

# %% [markdown]
# ## 第一类方法：线性方法

# %% [markdown]
# ## 第二类方法：非线性方法

# %% [markdown]
# ## 第四类方法：神经元网络
